# %%
# %reload_ext sql
# %sql sqlite:///lureshop.db
# Out:
# u'Connected: None@lureshop.db'

# %% [markdown]
# 1) Show all users in the lureshop db

# %%
# %%sql
# SELECT *
# FROM users
# Out:
# Done.
# [(1, u'granthaack@hush.com', u'granthaack', u't', u'2017-05-08 00:55:01.289228', u'2017-05-08 00:55:01.289228'),
#  (2, u'pj@yahoo.com', u'bASSfish92', u't', u'2017-05-08 00:55:30.578224', u'2017-05-08 00:55:30.578224'),
#  (3, u'realuser@yahoo.com', u'password', u'f', u'2017-05-08 00:55:45.760729', u'2017-05-08 00:55:45.760729'),
#  (4, u'grandpalure@fishing.com', u'ilovefishing', u'f', u'2017-05-08 00:56:01.137071', u'2017-05-08 00:56:01.137071'),
#  (5, u'notarussianhacker@kremlin.ru', u'putin', u'f', u'2017-05-08 00:56:28.709841', u'2017-05-08 00:56:28.709841'),
#  (6, u'dragnor@runscape.com', u'partyhat', u'f', u'2017-05-08 00:56:50.416085', u'2017-05-08 00:56:50.416085')]

# %% [markdown]
# 2) Show all purchases made in the lureshop db

# %%
# %%sql
# SELECT *
# FROM purchases
# Out:
# Done.
# [(u'4-4-2010', 3, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 0),
#  (u'2-14-2010', 3, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 1),
#  (u'2-14-2010', 6, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 2),
#  (u'4-1-2010', 2, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 3),
#  (u'6-3-2010', 1, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 4),
#  (u'6-4-2010', 1, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 5),
#  (u'6-4-2010', 4, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 6),
#  (u'6-4-2010', 4, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 7),
#  (u'7-1-2010', 3, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 8),
#  (u'7-13-2010', 1, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 9),
#  (u'7-18-2010', 3, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 10),
#  (u'7-18-2010', 1, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 11),
#  (u'8-1-2010', 2, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 12),
#  (u'8-16-2010', 2, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 13),
#  (u'8-18-2010', 1, 19, u'22:34:55:3:2', u'33:44:92:40:2:2', 14),
# ...

# %% [markdown]
# 3) Show all available items in the lureshop database

# %%
# %%sql
# SELECT *
# FROM items
# Out:
# Done.
# [(2, u'Livingston Walk N Pop 67 Tournament', 9.99, u'Poppers & Chuggers', u'Topwater', None, u'Livingston', u'2017-05-08 00:20:51.825838', u'2017-05-08 00:25:10.086408', None),
#  (3, u'Livingston Walk N Pop 77 Team', 13.99, u'Poppers & Chuggers', u'Topwater', None, u'Livingston', u'2017-05-08 00:21:27.590855', u'2017-05-08 00:25:19.039305', None),
#  (4, u'Lobina Ricos', 21.99, u'Poppers & Chuggers', u'Topwater', None, u'Ricos', u'2017-05-08 00:22:33.599264', u'2017-05-08 00:22:33.599264', None),
#  (5, u'Yellow Magic Japanese Popper', 15.95, u'Poppers & Chuggers', u'Topwater', None, u'Yellow Magic', u'2017-05-08 00:23:02.872649', u'2017-05-08 00:23:02.872649', None),
#  (6, u'6th Sense Crush Dogma Series Topwater', 9.99, u'Poppers & Chuggers', u'Topwater', None, u'6th Sense', u'2017-05-08 00:23:40.202884', u'2017-05-08 00:25:30.081378', None),
# ...

# %% [markdown]
# 4) Show all purchases in the database

# %%
# %%sql
# SELECT *
# FROM cart
# Out:
# Done.
# [(1, 18, 3, 15, u'22:34:55:3:2', u'33:66:32:90:2:1'),
#  (3, 15, 4, 12, u'22:34:55:3:1', u'33:66:32:90:2:3'),
#  (4, 8, 4, 12, u'32:34:55:3:2', u'33:86:62:10:2:1'),
#  (5, 1, 2, 10, u'22:34:55:3:2', u'33:66:30:93:2:5'),
#  (6, 1, 4, 22, u'32:34:55:3:3', u'33:66:31:99:2:5'),
#  (8, 11, 1, 5, u'21:34:55:3:2', u'33:22:82:90:2:1'),
#  (10, 1, 1, 35, u'22:34:55:3:3', u'33:66:62:98:2:4')]
